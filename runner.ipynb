# %%
import papermill as pm

# %% [markdown]
# # 20240223
# * e5-large-instruct

# %%
i = 27
model_id = "intfloat/multilingual-e5-large-instruct"
out_filename = f"{i}_{model_id.replace('/', '_')}.ipynb"
print(model_id, out_filename)
sts_prefix = "Instruct: Retrieve semantically similar text.\nQuery: "
retrieve_query_prefix = "Instruct: Given a question, retrieve Wikipedia passages that answer the question. \nQuery: "
retrieve_passage_prefix = ""

out_filename = f"{i}_{model_id.replace('/', '_')}.ipynb"
print(model_id, out_filename)
pm.execute_notebook(
    "template_sentence-transformers.ipynb",
    out_filename,
    parameters=dict(
        model_id=model_id,
        sts_prefix=sts_prefix,
        retrieve_query_prefix=retrieve_query_prefix,
        retrieve_passage_prefix=retrieve_passage_prefix,
    ),
)
# Out:
# Black is not installed, parameters wont be formatted
# intfloat/multilingual-e5-large-instruct 27_intfloat_multilingual-e5-large-instruct.ipynb
# intfloat/multilingual-e5-large-instruct 27_intfloat_multilingual-e5-large-instruct.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'ExecuteTime': {'end_time': '2023-10-07T08:50:45.949996Z',
#      'start_time': '2023-10-07T08:50:44.497041Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:09:53.690382',
#      'end_time': '2024-02-23T03:09:55.400550',
#      'duration': 1.710168,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:09:53.693909Z',
#      'iopub.execute_input': '2024-02-23T03:09:53.693909Z',
#      'shell.execute_reply': '2024-02-23T03:09:55.398549Z',
#      'iopub.status.idle': '2024-02-23T03:09:55.398549Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': 'True'},
#      'execution_count': 1}],
#    'source': 'import torch\n\ntorch.cuda.is_available()',
#    'id': 'a8e5f2f4'},
#   {'cell_type': 'code',
#    'execution_count': 2,
#    'metadata': {'ExecuteTime': {'end_time': '2023-10-07T08:50:45.965421Z',
#      'start_time': '2023-10-07T08:50:45.951998Z'},
#     'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:09:55.405068',
#      'end_time': '2024-02-23T03:09:55.414581',
#      'duration': 0.009513,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:09:55.409071Z',
#      'iopub.execute_input': '2024-02-23T03:09:55.410066Z',
#      'iopub.status.idle': '2024-02-23T03:09:55.413578Z',
#      'shell.execute_reply': '2024-02-23T03:09:55.413578Z'}},
#    'outputs': [],
#    'source': 'jsts_url = "https://raw.githubusercontent.com/yahoojapan/JGLUE/main/datasets/jsts-v1.1/valid-v1.1.json"\njsick_url = "https://github.com/verypluming/JSICK/raw/main/jsick/test.tsv"\nmiracle_n_hard_negs = 300\nmiracle_n_recall = 30\nsts_prefix = ""\nretrieve_query_prefix = ""\nretrieve_passage_prefix = ""',
#    'id': 'ca0db30e'},
#   {'id': 'e144a509',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:09:55.418579',
#      'end_time': '2024-02-23T03:09:55.431100',
#      'duration': 0.012521,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:09:55.424098Z',
#      'iopub.execute_input': '2024-02-23T03:09:55.424098Z',
#      'shell.execute_reply': '2024-02-23T03:09:55.429100Z',
#      'iopub.status.idle': '2024-02-23T03:09:55.430100Z'}},
#    'execution_count': 3,
#    'source': '# Parameters\nmodel_id = "intfloat/multilingual-e5-large-instruct"\nsts_prefix = "Instruct: Retrieve semantically similar text.\\nQuery: "\nretrieve_query_prefix = "Instruct: Given a question, retrieve Wikipedia passages that answer the question. \\nQuery: "\nretrieve_passage_prefix = ""\n',
#    'outputs': []},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:09:55.433607',
#      'end_time': '2024-02-23T03:09:55.438612',
#      'duration': 0.005005,
#      'status': 'completed'}},
#    'source': '# Model',
#    'id': '4550c8f9'},
#   {'cell_type': 'code',
#    'execution_count': 4,
#    'metadata': {'ExecuteTime': {'end_time': '2023-10-07T08:50:53.766453Z',
#      'start_time': '2023-10-07T08:50:51.631864Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:09:55.443137',
#      'end_time': '2024-02-23T03:11:55.507343',
#      'duration': 120.064206,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:09:55.447137Z',
#      'iopub.execute_input': '2024-02-23T03:09:55.448138Z',
#      'shell.execute_reply': '2024-02-23T03:11:55.505348Z',
#      'iopub.status.idle': '2024-02-23T03:11:55.505348Z'}},
#    'outputs': [{'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': 'Downloading modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]',
#       'application/vnd.jupyter.widget-view+json': {'version_major': 2,
#        'version_minor': 0,
#        'model_id': 'bc484b78c7b34cdb9d6a7a1ee1ce1717'}}},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': 'Downloading (…)ce_transformers.json:   0%|          | 0.00/128 [00:00<?, ?B/s]',
#       'application/vnd.jupyter.widget-view+json': {'version_major': 2,
#        'version_minor': 0,
#        'model_id': '22dc9aae6682499395ff6a5677f09420'}}},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'You try to use a model that was created with version 2.4.0.dev0, however, your version is 2.3.1. This might cause unexpected behavior or errors. In that case, try to update to the latest version.\n\n\n\n'},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': 'Downloading README.md:   0%|          | 0.00/140k [00:00<?, ?B/s]',
#       'application/vnd.jupyter.widget-view+json': {'version_major': 2,
#        'version_minor': 0,
#        'model_id': 'd5e0e9c052ef47f2af021ab6dad6493f'}}},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': 'Downloading config.json:   0%|          | 0.00/690 [00:00<?, ?B/s]',
#       'application/vnd.jupyter.widget-view+json': {'version_major': 2,
#        'version_minor': 0,
#        'model_id': 'ae64f354e2dc4146b88531e9e4086e77'}}},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'c:\\Users\\yokonami\\repos_oshizo\\JapaneseEmbeddingEval\\venv\\lib\\site-packages\\transformers\\utils\\generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.\n  torch.utils._pytree._register_pytree_node(\n'},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'c:\\Users\\yokonami\\repos_oshizo\\JapaneseEmbeddingEval\\venv\\lib\\site-packages\\transformers\\utils\\generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.\n  torch.utils._pytree._register_pytree_node(\n'},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': 'Downloading model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]',
#       'application/vnd.jupyter.widget-view+json': {'version_major': 2,
#        'version_minor': 0,
#        'model_id': '74518d974fb14a5c94b6e5ba77b4eada'}}},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': 'Downloading tokenizer_config.json:   0%|          | 0.00/1.18k [00:00<?, ?B/s]',
#       'application/vnd.jupyter.widget-view+json': {'version_major': 2,
#        'version_minor': 0,
#        'model_id': '9863ba1367c14c85881347d79acbbf8e'}}},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': 'Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]',
#       'application/vnd.jupyter.widget-view+json': {'version_major': 2,
#        'version_minor': 0,
#        'model_id': 'f971e2894e30475793820c9b57c6b127'}}},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': 'Downloading tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]',
#       'application/vnd.jupyter.widget-view+json': {'version_major': 2,
#        'version_minor': 0,
#        'model_id': '1ba6a11232c74f69adc08ce29ef06f2a'}}},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': 'Downloading (…)cial_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]',
#       'application/vnd.jupyter.widget-view+json': {'version_major': 2,
#        'version_minor': 0,
#        'model_id': '826b7aef7cd04510b3f5e4d78645374e'}}},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': 'Downloading 1_Pooling/config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]',
#       'application/vnd.jupyter.widget-view+json': {'version_major': 2,
#        'version_minor': 0,
#        'model_id': 'ada9fa4ca2a44e42bae6fcfdfe0c53fe'}}}],
#    'source': 'from sentence_transformers import SentenceTransformer\n\nmodel = SentenceTransformer(model_id)\nmodel.max_seq_length = 512',
#    'id': '67638a1b'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:11:55.511880',
#      'end_time': '2024-02-23T03:11:55.515880',
#      'duration': 0.004,
#      'status': 'completed'}},
#    'source': '# JSTS',
#    'id': '1b563a99'},
#   {'cell_type': 'code',
#    'execution_count': 5,
#    'metadata': {'ExecuteTime': {'end_time': '2023-10-07T08:50:54.215161Z',
#      'start_time': '2023-10-07T08:50:53.767452Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:11:55.520852',
#      'end_time': '2024-02-23T03:11:55.900883',
#      'duration': 0.380031,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:11:55.524860Z',
#      'iopub.execute_input': '2024-02-23T03:11:55.525890Z',
#      'iopub.status.idle': '2024-02-23T03:11:55.899843Z',
#      'shell.execute_reply': '2024-02-23T03:11:55.899340Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '  sentence_pair_id               yjcaptions_id                    sentence1  \\\n0                0  100312_421853-104611-31624  レンガの建物の前を、乳母車を押した女性が歩いています。   \n\n            sentence2  label  \n0  厩舎で馬と女性とが寄り添っています。    0.0  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>sentence_pair_id</th>\n      <th>yjcaptions_id</th>\n      <th>sentence1</th>\n      <th>sentence2</th>\n      <th>label</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>100312_421853-104611-31624</td>\n      <td>レンガの建物の前を、乳母車を押した女性が歩いています。</td>\n      <td>厩舎で馬と女性とが寄り添っています。</td>\n      <td>0.0</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 5}],
#    'source': 'import json\nimport pandas as pd\nfrom urllib.request import urlopen\n\ndf = pd.DataFrame([json.loads(line) for line in urlopen(jsts_url).readlines()])\ndf.head(1)',
#    'id': '20700874'},
#   {'cell_type': 'code',
#    'execution_count': 6,
#    'metadata': {'ExecuteTime': {'end_time': '2023-10-07T08:50:54.230679Z',
#      'start_time': '2023-10-07T08:50:54.218161Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:11:55.904852',
#      'end_time': '2024-02-23T03:11:55.916378',
#      'duration': 0.011526,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:11:55.910365Z',
#      'iopub.execute_input': '2024-02-23T03:11:55.910365Z',
#      'shell.execute_reply': '2024-02-23T03:11:55.914490Z',
#      'iopub.status.idle': '2024-02-23T03:11:55.914490Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(1457, 5)'},
#      'execution_count': 6}],
#    'source': 'df.shape',
#    'id': '8b4a9c26'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:11:55.919934',
#      'end_time': '2024-02-23T03:11:55.923939',
#      'duration': 0.004005,
#      'status': 'completed'}},
#    'source': '## Encode',
#    'id': 'abc5efda'},
#   {'cell_type': 'code',
#    'execution_count': 7,
#    'metadata': {'ExecuteTime': {'end_time': '2023-10-07T08:50:57.800419Z',
#      'start_time': '2023-10-07T08:50:54.234207Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:11:55.927812',
#      'end_time': '2024-02-23T03:12:08.932039',
#      'duration': 13.004227,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:11:55.932358Z',
#      'iopub.execute_input': '2024-02-23T03:11:55.933377Z',
#      'shell.execute_reply': '2024-02-23T03:12:08.931035Z',
#      'iopub.status.idle': '2024-02-23T03:12:08.931035Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '((1457, 1024), (1457, 1024))'},
#      'execution_count': 7}],
#    'source': 'sentence1_embs = model.encode(sts_prefix + df["sentence1"])\nsentence2_embs = model.encode(sts_prefix + df["sentence2"])\nsentence1_embs.shape, sentence2_embs.shape',
#    'id': '108ae734'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:12:08.937527',
#      'end_time': '2024-02-23T03:12:08.942513',
#      'duration': 0.004986,
#      'status': 'completed'}},
#    'source': '## Correlation Score',
#    'id': '5e90fdfb'},
#   {'cell_type': 'code',
#    'execution_count': 8,
#    'metadata': {'ExecuteTime': {'end_time': '2023-10-07T08:50:57.847350Z',
#      'start_time': '2023-10-07T08:50:57.801925Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:12:08.946936',
#      'end_time': '2024-02-23T03:12:09.009217',
#      'duration': 0.062281,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:12:08.951943Z',
#      'iopub.execute_input': '2024-02-23T03:12:08.951943Z',
#      'shell.execute_reply': '2024-02-23T03:12:09.007229Z',
#      'iopub.status.idle': '2024-02-23T03:12:09.008195Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '0.8324750544227347'},
#      'execution_count': 8}],
#    'source': 'from scipy.spatial.distance import cosine, euclidean\nfrom scipy.stats import spearmanr\n\ndf["similarity"] = [\n    1 - cosine(s1, s2) for s1, s2 in zip(sentence1_embs, sentence2_embs)\n]\njsts_score = spearmanr(df["similarity"], df["label"])[0]\njsts_score',
#    'id': 'caedde24'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:12:09.014194',
#      'end_time': '2024-02-23T03:12:09.022706',
#      'duration': 0.008512,
#      'status': 'completed'}},
#    'source': '# JSICK',
#    'id': 'afea6e6e'},
#   {'cell_type': 'code',
#    'execution_count': 9,
#    'metadata': {'ExecuteTime': {'end_time': '2023-10-07T08:51:00.645301Z',
#      'start_time': '2023-10-07T08:51:00.119204Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:12:09.028252',
#      'end_time': '2024-02-23T03:12:10.015159',
#      'duration': 0.986907,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:12:09.035248Z',
#      'iopub.execute_input': '2024-02-23T03:12:09.035248Z',
#      'shell.execute_reply': '2024-02-23T03:12:10.013654Z',
#      'iopub.status.idle': '2024-02-23T03:12:10.013654Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '   pair_ID  data                                      sentence_A_En  \\\n0        6  test  There is no boy playing outdoors and there is ...   \n\n                                       sentence_B_En entailment_label_En  \\\n0  A group of kids is playing in a yard and an ol...             neutral   \n\n   relatedness_score_En corr_entailment_labelAB_En corr_entailment_labelBA_En  \\\n0                   3.3                        NaN                        NaN   \n\n                        sentence_A_Ja                          sentence_B_Ja  \\\n0  戸外で遊んでいる男の子は一人もおらず、微笑んでいる男性は一人もいない  子供たちのグループが庭で遊んでいて、後ろの方には年を取った男性が立っている   \n\n  entailment_label_Ja  relatedness_score_Ja                   image_ID  \\\n0       contradiction                   2.3  3155657768_b83a7831e5.jpg   \n\n                                    original_caption        semtag_short  \\\n0  The children are playing outdoors , while a ma...  Negation#Numerical   \n\n                                         semtag_long  \n0  Numerical;人;名詞,接尾,助数詞,*#Negation;ない;助動詞,*,*,*#...  ',
#       'text/html': '<div>\n<style scoped>\n    .dataframe tbody tr th:only-of-type {\n        vertical-align: middle;\n    }\n\n    .dataframe tbody tr th {\n        vertical-align: top;\n    }\n\n    .dataframe thead th {\n        text-align: right;\n    }\n</style>\n<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>pair_ID</th>\n      <th>data</th>\n      <th>sentence_A_En</th>\n      <th>sentence_B_En</th>\n      <th>entailment_label_En</th>\n      <th>relatedness_score_En</th>\n      <th>corr_entailment_labelAB_En</th>\n      <th>corr_entailment_labelBA_En</th>\n      <th>sentence_A_Ja</th>\n      <th>sentence_B_Ja</th>\n      <th>entailment_label_Ja</th>\n      <th>relatedness_score_Ja</th>\n      <th>image_ID</th>\n      <th>original_caption</th>\n      <th>semtag_short</th>\n      <th>semtag_long</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>6</td>\n      <td>test</td>\n      <td>There is no boy playing outdoors and there is ...</td>\n      <td>A group of kids is playing in a yard and an ol...</td>\n      <td>neutral</td>\n      <td>3.3</td>\n      <td>NaN</td>\n      <td>NaN</td>\n      <td>戸外で遊んでいる男の子は一人もおらず、微笑んでいる男性は一人もいない</td>\n      <td>子供たちのグループが庭で遊んでいて、後ろの方には年を取った男性が立っている</td>\n      <td>contradiction</td>\n      <td>2.3</td>\n      <td>3155657768_b83a7831e5.jpg</td>\n      <td>The children are playing outdoors , while a ma...</td>\n      <td>Negation#Numerical</td>\n      <td>Numerical;人;名詞,接尾,助数詞,*#Negation;ない;助動詞,*,*,*#...</td>\n    </tr>\n  </tbody>\n</table>\n</div>'},
#      'execution_count': 9}],
#    'source': 'df = pd.read_csv(jsick_url, sep="\\t")\ndf.head(1)',
#    'id': '35716419'},
#   {'cell_type': 'code',
#    'execution_count': 10,
#    'metadata': {'ExecuteTime': {'end_time': '2023-10-07T08:51:00.660322Z',
#      'start_time': '2023-10-07T08:51:00.647809Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:12:10.020712',
#      'end_time': '2024-02-23T03:12:10.047305',
#      'duration': 0.026593,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:12:10.027262Z',
#      'iopub.execute_input': '2024-02-23T03:12:10.027262Z',
#      'shell.execute_reply': '2024-02-23T03:12:10.045393Z',
#      'iopub.status.idle': '2024-02-23T03:12:10.046308Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(4927, 16)'},
#      'execution_count': 10}],
#    'source': 'df.shape',
#    'id': 'a08653ef'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:12:10.052303',
#      'end_time': '2024-02-23T03:12:10.058832',
#      'duration': 0.006529,
#      'status': 'completed'}},
#    'source': '## Encode',
#    'id': '1ccdd08a'},
#   {'cell_type': 'code',
#    'execution_count': 11,
#    'metadata': {'ExecuteTime': {'end_time': '2023-10-07T08:51:06.645910Z',
#      'start_time': '2023-10-07T08:51:01.623993Z'},
#     'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:12:10.063830',
#      'end_time': '2024-02-23T03:12:51.616545',
#      'duration': 41.552715,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:12:10.070347Z',
#      'iopub.execute_input': '2024-02-23T03:12:10.070347Z',
#      'iopub.status.idle': '2024-02-23T03:12:51.614123Z',
#      'shell.execute_reply': '2024-02-23T03:12:51.613148Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '((4927, 1024), (4927, 1024))'},
#      'execution_count': 11}],
#    'source': 'sentence1_embs = model.encode(sts_prefix + df["sentence_A_Ja"])\nsentence2_embs = model.encode(sts_prefix + df["sentence_B_Ja"])\nsentence1_embs.shape, sentence2_embs.shape',
#    'id': '58e7afed'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:12:51.621545',
#      'end_time': '2024-02-23T03:12:51.626060',
#      'duration': 0.004515,
#      'status': 'completed'}},
#    'source': '## Correlation Score',
#    'id': '5b7c5dd8'},
#   {'cell_type': 'code',
#    'execution_count': 12,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:12:51.632068',
#      'end_time': '2024-02-23T03:12:51.813848',
#      'duration': 0.18178,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:12:51.668479Z',
#      'iopub.execute_input': '2024-02-23T03:12:51.668479Z',
#      'shell.execute_reply': '2024-02-23T03:12:51.811884Z',
#      'iopub.status.idle': '2024-02-23T03:12:51.811884Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '0.8221945002561732'},
#      'execution_count': 12}],
#    'source': 'from scipy.spatial.distance import cosine\nfrom scipy.stats import spearmanr\n\ndf["similarity"] = [\n    1 - cosine(s1, s2) for s1, s2 in zip(sentence1_embs, sentence2_embs)\n]\njsick_score = spearmanr(df["similarity"], df["relatedness_score_Ja"])[0]\njsick_score',
#    'id': '328be461'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:12:51.819371',
#      'end_time': '2024-02-23T03:12:51.824358',
#      'duration': 0.004987,
#      'status': 'completed'}},
#    'source': '# Miracle\n* Need access token for huggingface',
#    'id': '54df81b8'},
#   {'cell_type': 'code',
#    'execution_count': 13,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:12:51.829899',
#      'end_time': '2024-02-23T03:12:51.859555',
#      'duration': 0.029656,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:12:51.835503Z',
#      'iopub.execute_input': '2024-02-23T03:12:51.836435Z',
#      'shell.execute_reply': '2024-02-23T03:12:51.857645Z',
#      'iopub.status.idle': '2024-02-23T03:12:51.858524Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': 'True'},
#      'execution_count': 13}],
#    'source': 'import os\nimport dotenv\n\ndotenv.load_dotenv("huggingface_access_token", override=True)',
#    'id': 'd6f5670b'},
#   {'cell_type': 'code',
#    'execution_count': 14,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:12:51.864526',
#      'end_time': '2024-02-23T03:12:54.207441',
#      'duration': 2.342915,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:12:51.871141Z',
#      'iopub.execute_input': '2024-02-23T03:12:51.871141Z',
#      'iopub.status.idle': '2024-02-23T03:12:54.205482Z',
#      'shell.execute_reply': '2024-02-23T03:12:54.205482Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'Found cached dataset miracl (G:/cache/miracl___miracl/ja/1.0.0/f598b4ee332f2b16e82c6c83ab1ba82e1a7777ef82e7ce3c1416f6b20a142313)\n'},
#     {'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "Dataset({\n    features: ['query_id', 'query', 'positive_passages', 'negative_passages'],\n    num_rows: 860\n})"},
#      'execution_count': 14}],
#    'source': 'import datasets\n\n# query and positives\nds = datasets.load_dataset(\n    "miracl/miracl", "ja", use_auth_token=os.environ["HF_ACCESS_TOKEN"], split="dev"\n)\nds',
#    'id': '7be0209b'},
#   {'cell_type': 'code',
#    'execution_count': 15,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:12:54.212440',
#      'end_time': '2024-02-23T03:13:02.223907',
#      'duration': 8.011467,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:12:54.218983Z',
#      'iopub.execute_input': '2024-02-23T03:12:54.218983Z',
#      'shell.execute_reply': '2024-02-23T03:13:02.222908Z',
#      'iopub.status.idle': '2024-02-23T03:13:02.222908Z'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': 'Found cached dataset miracl-corpus (G:/cache/miracl___miracl-corpus/ja/1.0.0/16b566312c83a2e1f94d0813c8702b464b97f6b8959336adf062d289ce9b51fa)\n'},
#     {'output_type': 'display_data',
#      'metadata': {},
#      'data': {'text/plain': '  0%|          | 0/1 [00:00<?, ?it/s]',
#       'application/vnd.jupyter.widget-view+json': {'version_major': 2,
#        'version_minor': 0,
#        'model_id': 'ee034f4e2f08473c88acae0affcdd524'}}},
#     {'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "DatasetDict({\n    train: Dataset({\n        features: ['docid', 'title', 'text'],\n        num_rows: 6953614\n    })\n})"},
#      'execution_count': 15}],
#    'source': '# all corpus texts\ncorpus = datasets.load_dataset("miracl/miracl-corpus", "ja")\ncorpus',
#    'id': 'da86c4cb'},
#   {'cell_type': 'code',
#    'execution_count': 16,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:13:02.230428',
#      'end_time': '2024-02-23T03:13:02.440657',
#      'duration': 0.210229,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:13:02.236672Z',
#      'iopub.execute_input': '2024-02-23T03:13:02.237675Z',
#      'shell.execute_reply': '2024-02-23T03:13:02.438675Z',
#      'iopub.status.idle': '2024-02-23T03:13:02.438675Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "(860,\n ['0', '3', '4', '5', '7'],\n dict_keys(['docids', 'indices']),\n ['2681119#0', '2681119#1'],\n [1393435, 1393436])"},
#      'execution_count': 16}],
#    'source': '# hard negatives\nwith open("./miracl_hard_negs_1000.json") as f:\n    hn = json.loads(f.read())\nlen(hn), list(hn.keys())[:5], hn["0"].keys(), hn["0"]["docids"][:2], hn["0"]["indices"][\n    :2\n]',
#    'id': '2825fd05'},
#   {'cell_type': 'code',
#    'execution_count': 17,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T03:13:02.447194',
#      'end_time': '2024-02-23T05:18:42.920000',
#      'duration': 7540.472806,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T03:13:02.453190Z',
#      'iopub.execute_input': '2024-02-23T03:13:02.454194Z',
#      'iopub.status.idle': '2024-02-23T05:18:42.893068Z',
#      'shell.execute_reply': '2024-02-23T05:18:42.890538Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': '(1790, 1568, 0.8759776536312849)'},
#      'execution_count': 17}],
#    'source': 'import numpy as np\nimport pandas as pd\nfrom scipy.spatial.distance import cdist\n\n\ndef get_text(corpus_item):\n    return corpus_item["title"] + " " + corpus_item["text"]\n\n\ncorpus_dict = {item["docid"]: get_text(item) for item in corpus["train"]}\n\nn_total_pos = 0\nn_total_tp = 0\n\nfor item in ds:\n    # query\n    query_emb = model.encode([retrieve_query_prefix + item["query"]])\n\n    # passages are set(300 hard negatives + positives)\n    positive_docids = [pp["docid"] for pp in item["positive_passages"]]\n    positive_texts = [get_text(pp) for pp in item["positive_passages"]]\n    hn_docids = hn[item["query_id"]]["docids"][:miracle_n_hard_negs]\n\n    # drop hard negatives in positives\n    hn_docids = [docid for docid in hn_docids if docid not in positive_docids]\n\n    # search target\n    target_docids = positive_docids + hn_docids\n    target_texts = positive_texts + [corpus_dict[docid] for docid in hn_docids]\n\n    # embedding\n    target_embs = model.encode(\n        [retrieve_passage_prefix + text for text in target_texts]\n    )\n\n    # topK\n    topk_indices = np.argsort(cdist(query_emb, target_embs, metric="cosine"))[0][\n        :miracle_n_recall\n    ]\n\n    n_pos = len(positive_docids)\n    n_tp = len(\n        set(topk_indices) & set(range(len(positive_docids)))\n    )  # positives are first indices\n\n    n_total_pos += n_pos\n    n_total_tp += n_tp\n\n    # if n_pos > n_tp:\n    # print(f"{item[\'query_id\']}:{n_tp}/{n_pos}", end=", ")\n\nmiracl_recall = n_total_tp / n_total_pos\n\nn_total_pos, n_total_tp, miracl_recall',
#    'id': '0c62f945'},
#   {'cell_type': 'markdown',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T05:18:42.930533',
#      'end_time': '2024-02-23T05:18:42.937118',
#      'duration': 0.006585,
#      'status': 'completed'}},
#    'source': '# Output',
#    'id': 'f6c1bc4a'},
#   {'cell_type': 'code',
#    'execution_count': 18,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T05:18:42.942071',
#      'end_time': '2024-02-23T05:18:42.968524',
#      'duration': 0.026453,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T05:18:42.949290Z',
#      'iopub.execute_input': '2024-02-23T05:18:42.950325Z',
#      'iopub.status.idle': '2024-02-23T05:18:42.966375Z',
#      'shell.execute_reply': '2024-02-23T05:18:42.966375Z'}},
#    'outputs': [{'output_type': 'execute_result',
#      'metadata': {},
#      'data': {'text/plain': "('intfloat/multilingual-e5-large-instruct',\n 0.8324750544227347,\n 0.8221945002561732,\n 0.8759776536312849)"},
#      'execution_count': 18}],
#    'source': 'model_id, jsts_score, jsick_score, miracl_recall',
#    'id': 'fa6fe4b4'},
#   {'cell_type': 'code',
#    'execution_count': 19,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2024-02-23T05:18:42.973038',
#      'end_time': '2024-02-23T05:18:42.998404',
#      'duration': 0.025366,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2024-02-23T05:18:42.980043Z',
#      'iopub.execute_input': '2024-02-23T05:18:42.980043Z',
#      'shell.execute_reply': '2024-02-23T05:18:42.996404Z',
#      'iopub.status.idle': '2024-02-23T05:18:42.997416Z'}},
#    'outputs': [],
#    'source': 'import json\n\nwith open(f\'./scores/{model_id.replace("/", "_")}.txt\', "w") as f:\n    f.write(\n        json.dumps(\n            {\n                "model_id": model_id,\n                "jsts": jsts_score,\n                "jsick": jsick_score,\n                "miracl": miracl_recall,\n            }\n        )\n    )',
#    'id': 'dc97c4fd'}],
#  'metadata': {'kernelspec': {'display_name': 'Python 3 (ipykernel)',
#    'language': 'python',
#    'name': 'python3'},
#   'language_info': {'name': 'python',
#    'version': '3.9.11',
#    'mimetype': 'text/x-python',
#    'codemirror_mode': {'name': 'ipython', 'version': 3},
#    'pygments_lexer': 'ipython3',
#    'nbconvert_exporter': 'python',
#    'file_extension': '.py'},
#   'toc': {'base_numbering': 1,
#    'nav_menu': {},
#    'number_sections': True,
#    'sideBar': True,
#    'skip_h1_title': False,
#    'title_cell': 'Table of Contents',
#    'title_sidebar': 'Contents',
#    'toc_cell': False,
#    'toc_position': {},
#    'toc_section_display': True,
#    'toc_window_display': False},
#   'vscode': {'interpreter': {'hash': '02c2702a58ea2fe60fd5f26dd152a70e7993d77024040a4f035d0ea16923b730'}},
#   'orig_nbformat_minor': 2,
#   'papermill': {'default_parameters': {},
#    'parameters': {'model_id': 'intfloat/multilingual-e5-large-instruct',
#     'sts_prefix': 'Instruct: Retrieve semantically similar text.\nQuery: ',
#     'retrieve_query_prefix': 'Instruct: Given a question, retrieve Wikipedia passages that answer the question. \nQuery: ',
#     'retrieve_passage_prefix': ''},
#    'environment_variables': {},
#    'version': '2.4.0',
#    'input_path': 'template_sentence-transformers.ipynb',
#    'output_path': '27_intfloat_multilingual-e5-large-instruct.ipynb',
#    'start_time': '2024-02-23T03:09:52.395144',
#    'end_time': '2024-02-23T05:18:45.653749',
#    'duration': 7733.258605,
#    'exception': None},
#   'widgets': {'application/vnd.jupyter.widget-state+json': {'state': {'ad11b9486ea84e429162e2593bea6b77': {'model_name': 'LayoutModel',
#       'model_module': '@jupyter-widgets/base',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/base',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'LayoutModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'LayoutView',
#        'align_content': None,
#        'align_items': None,
#        'align_self': None,
#        'border_bottom': None,
#        'border_left': None,
#        'border_right': None,
#        'border_top': None,
#        'bottom': None,
#        'display': None,
#        'flex': None,
#        'flex_flow': None,
#        'grid_area': None,
#        'grid_auto_columns': None,
#        'grid_auto_flow': None,
#        'grid_auto_rows': None,
#        'grid_column': None,
#        'grid_gap': None,
#        'grid_row': None,
#        'grid_template_areas': None,
#        'grid_template_columns': None,
#        'grid_template_rows': None,
#        'height': None,
#        'justify_content': None,
#        'justify_items': None,
#        'left': None,
#        'margin': None,
#        'max_height': None,
#        'max_width': None,
#        'min_height': None,
#        'min_width': None,
#        'object_fit': None,
#        'object_position': None,
#        'order': None,
#        'overflow': None,
#        'padding': None,
#        'right': None,
#        'top': None,
#        'visibility': None,
#        'width': None}},
#      'cb09324caab34737bd0661ffb429bfc3': {'model_name': 'ProgressStyleModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'ProgressStyleModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'StyleView',
#        'bar_color': None,
#        'description_width': ''}},
#      '9f52300816f54db2a1f35822719ddc76': {'model_name': 'FloatProgressModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_dom_classes': [],
#        '_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'FloatProgressModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/controls',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'ProgressView',
#        'bar_style': 'success',
#        'description': '',
#        'description_allow_html': False,
#        'layout': 'IPY_MODEL_ad11b9486ea84e429162e2593bea6b77',
#        'max': 349.0,
#        'min': 0.0,
#        'orientation': 'horizontal',
#        'style': 'IPY_MODEL_cb09324caab34737bd0661ffb429bfc3',
#        'tabbable': None,
#        'tooltip': None,
#        'value': 349.0}},
#      'b38e480e2afe4565b51d3d23c169e694': {'model_name': 'LayoutModel',
#       'model_module': '@jupyter-widgets/base',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/base',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'LayoutModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'LayoutView',
#        'align_content': None,
#        'align_items': None,
#        'align_self': None,
#        'border_bottom': None,
#        'border_left': None,
#        'border_right': None,
#        'border_top': None,
#        'bottom': None,
#        'display': None,
#        'flex': None,
#        'flex_flow': None,
#        'grid_area': None,
#        'grid_auto_columns': None,
#        'grid_auto_flow': None,
#        'grid_auto_rows': None,
#        'grid_column': None,
#        'grid_gap': None,
#        'grid_row': None,
#        'grid_template_areas': None,
#        'grid_template_columns': None,
#        'grid_template_rows': None,
#        'height': None,
#        'justify_content': None,
#        'justify_items': None,
#        'left': None,
#        'margin': None,
#        'max_height': None,
#        'max_width': None,
#        'min_height': None,
#        'min_width': None,
#        'object_fit': None,
#        'object_position': None,
#        'order': None,
#        'overflow': None,
#        'padding': None,
#        'right': None,
#        'top': None,
#        'visibility': None,
#        'width': None}},
#      'e150da76dfb84b64b1c4d186c39adf3d': {'model_name': 'HTMLStyleModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'HTMLStyleModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'StyleView',
#        'background': None,
#        'description_width': '',
#        'font_size': None,
#        'text_color': None}},
#      '749ce831e2794cfead51aee0938a2661': {'model_name': 'HTMLModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_dom_classes': [],
#        '_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'HTMLModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/controls',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'HTMLView',
#        'description': '',
#        'description_allow_html': False,
#        'layout': 'IPY_MODEL_b38e480e2afe4565b51d3d23c169e694',
#        'placeholder': '\u200b',
#        'style': 'IPY_MODEL_e150da76dfb84b64b1c4d186c39adf3d',
#        'tabbable': None,
#        'tooltip': None,
#        'value': 'Downloading modules.json: 100%'}},
#      'e33c3d9c8f72457694c0e806f44370b4': {'model_name': 'LayoutModel',
#       'model_module': '@jupyter-widgets/base',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/base',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'LayoutModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'LayoutView',
#        'align_content': None,
#        'align_items': None,
#        'align_self': None,
#        'border_bottom': None,
#        'border_left': None,
#        'border_right': None,
#        'border_top': None,
#        'bottom': None,
#        'display': None,
#        'flex': None,
#        'flex_flow': None,
#        'grid_area': None,
#        'grid_auto_columns': None,
#        'grid_auto_flow': None,
#        'grid_auto_rows': None,
#        'grid_column': None,
#        'grid_gap': None,
#        'grid_row': None,
#        'grid_template_areas': None,
#        'grid_template_columns': None,
#        'grid_template_rows': None,
#        'height': None,
#        'justify_content': None,
#        'justify_items': None,
#        'left': None,
#        'margin': None,
#        'max_height': None,
#        'max_width': None,
#        'min_height': None,
#        'min_width': None,
#        'object_fit': None,
#        'object_position': None,
#        'order': None,
#        'overflow': None,
#        'padding': None,
#        'right': None,
#        'top': None,
#        'visibility': None,
#        'width': None}},
#      '32ef3661522744389758870cd0f9abeb': {'model_name': 'HTMLStyleModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'HTMLStyleModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'StyleView',
#        'background': None,
#        'description_width': '',
#        'font_size': None,
#        'text_color': None}},
#      '3bbaf59d3a4247859d9cc182cf704aec': {'model_name': 'HTMLModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_dom_classes': [],
#        '_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'HTMLModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/controls',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'HTMLView',
#        'description': '',
#        'description_allow_html': False,
#        'layout': 'IPY_MODEL_e33c3d9c8f72457694c0e806f44370b4',
#        'placeholder': '\u200b',
#        'style': 'IPY_MODEL_32ef3661522744389758870cd0f9abeb',
#        'tabbable': None,
#        'tooltip': None,
#        'value': ' 349/349 [00:00&lt;00:00, 44.0kB/s]'}},
#      '592496fb4f404794af024aaa202ab701': {'model_name': 'LayoutModel',
#       'model_module': '@jupyter-widgets/base',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/base',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'LayoutModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'LayoutView',
#        'align_content': None,
#        'align_items': None,
#        'align_self': None,
#        'border_bottom': None,
#        'border_left': None,
#        'border_right': None,
#        'border_top': None,
#        'bottom': None,
#        'display': None,
#        'flex': None,
#        'flex_flow': None,
#        'grid_area': None,
#        'grid_auto_columns': None,
#        'grid_auto_flow': None,
#        'grid_auto_rows': None,
#        'grid_column': None,
#        'grid_gap': None,
#        'grid_row': None,
#        'grid_template_areas': None,
#        'grid_template_columns': None,
#        'grid_template_rows': None,
#        'height': None,
#        'justify_content': None,
#        'justify_items': None,
#        'left': None,
#        'margin': None,
#        'max_height': None,
#        'max_width': None,
#        'min_height': None,
#        'min_width': None,
#        'object_fit': None,
#        'object_position': None,
#        'order': None,
#        'overflow': None,
#        'padding': None,
#        'right': None,
#        'top': None,
#        'visibility': None,
#        'width': None}},
#      'bc484b78c7b34cdb9d6a7a1ee1ce1717': {'model_name': 'HBoxModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_dom_classes': [],
#        '_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'HBoxModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/controls',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'HBoxView',
#        'box_style': '',
#        'children': ['IPY_MODEL_749ce831e2794cfead51aee0938a2661',
#         'IPY_MODEL_9f52300816f54db2a1f35822719ddc76',
#         'IPY_MODEL_3bbaf59d3a4247859d9cc182cf704aec'],
#        'layout': 'IPY_MODEL_592496fb4f404794af024aaa202ab701',
#        'tabbable': None,
#        'tooltip': None}},
#      '26da0fb8b2ed41a6b87fc61486da98cb': {'model_name': 'LayoutModel',
#       'model_module': '@jupyter-widgets/base',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/base',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'LayoutModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'LayoutView',
#        'align_content': None,
#        'align_items': None,
#        'align_self': None,
#        'border_bottom': None,
#        'border_left': None,
#        'border_right': None,
#        'border_top': None,
#        'bottom': None,
#        'display': None,
#        'flex': None,
#        'flex_flow': None,
#        'grid_area': None,
#        'grid_auto_columns': None,
#        'grid_auto_flow': None,
#        'grid_auto_rows': None,
#        'grid_column': None,
#        'grid_gap': None,
#        'grid_row': None,
#        'grid_template_areas': None,
#        'grid_template_columns': None,
#        'grid_template_rows': None,
#        'height': None,
#        'justify_content': None,
#        'justify_items': None,
#        'left': None,
#        'margin': None,
#        'max_height': None,
#        'max_width': None,
#        'min_height': None,
#        'min_width': None,
#        'object_fit': None,
#        'object_position': None,
#        'order': None,
#        'overflow': None,
#        'padding': None,
#        'right': None,
#        'top': None,
#        'visibility': None,
#        'width': None}},
#      '777cbbde042a41fe82747bd3f46b5215': {'model_name': 'ProgressStyleModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'ProgressStyleModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'StyleView',
#        'bar_color': None,
#        'description_width': ''}},
#      'ac8fa31733bc441494879d68250dcb41': {'model_name': 'FloatProgressModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_dom_classes': [],
#        '_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'FloatProgressModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/controls',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'ProgressView',
#        'bar_style': 'success',
#        'description': '',
#        'description_allow_html': False,
#        'layout': 'IPY_MODEL_26da0fb8b2ed41a6b87fc61486da98cb',
#        'max': 128.0,
#        'min': 0.0,
#        'orientation': 'horizontal',
#        'style': 'IPY_MODEL_777cbbde042a41fe82747bd3f46b5215',
#        'tabbable': None,
#        'tooltip': None,
#        'value': 128.0}},
#      'ddb9eef466b74754ac70a84fd1f6bc0b': {'model_name': 'LayoutModel',
#       'model_module': '@jupyter-widgets/base',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/base',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'LayoutModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'LayoutView',
#        'align_content': None,
#        'align_items': None,
#        'align_self': None,
#        'border_bottom': None,
#        'border_left': None,
#        'border_right': None,
#        'border_top': None,
#        'bottom': None,
#        'display': None,
#        'flex': None,
#        'flex_flow': None,
#        'grid_area': None,
#        'grid_auto_columns': None,
#        'grid_auto_flow': None,
#        'grid_auto_rows': None,
#        'grid_column': None,
#        'grid_gap': None,
#        'grid_row': None,
#        'grid_template_areas': None,
#        'grid_template_columns': None,
#        'grid_template_rows': None,
#        'height': None,
#        'justify_content': None,
#        'justify_items': None,
#        'left': None,
#        'margin': None,
#        'max_height': None,
#        'max_width': None,
#        'min_height': None,
#        'min_width': None,
#        'object_fit': None,
#        'object_position': None,
#        'order': None,
#        'overflow': None,
#        'padding': None,
#        'right': None,
#        'top': None,
#        'visibility': None,
#        'width': None}},
#      'f61005127814424a996ac41114c8459b': {'model_name': 'HTMLStyleModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'HTMLStyleModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'StyleView',
#        'background': None,
#        'description_width': '',
#        'font_size': None,
#        'text_color': None}},
#      '7321c123ae154d1a99c4fca9ccb2ce47': {'model_name': 'HTMLModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_dom_classes': [],
#        '_model_module': '@jupyter-widgets/controls',
# ...
#        '_model_module_version': '2.0.0',
#        '_model_name': 'LayoutModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'LayoutView',
#        'align_content': None,
#        'align_items': None,
#        'align_self': None,
#        'border_bottom': None,
#        'border_left': None,
#        'border_right': None,
#        'border_top': None,
#        'bottom': None,
#        'display': None,
#        'flex': None,
#        'flex_flow': None,
#        'grid_area': None,
#        'grid_auto_columns': None,
#        'grid_auto_flow': None,
#        'grid_auto_rows': None,
#        'grid_column': None,
#        'grid_gap': None,
#        'grid_row': None,
#        'grid_template_areas': None,
#        'grid_template_columns': None,
#        'grid_template_rows': None,
#        'height': None,
#        'justify_content': None,
#        'justify_items': None,
#        'left': None,
#        'margin': None,
#        'max_height': None,
#        'max_width': None,
#        'min_height': None,
#        'min_width': None,
#        'object_fit': None,
#        'object_position': None,
#        'order': None,
#        'overflow': None,
#        'padding': None,
#        'right': None,
#        'top': None,
#        'visibility': None,
#        'width': None}},
#      '2f017efd8e4b4642a16263f3c5a773f6': {'model_name': 'HTMLStyleModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'HTMLStyleModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'StyleView',
#        'background': None,
#        'description_width': '',
#        'font_size': None,
#        'text_color': None}},
#      '943161e1a2054ef39b0c2e51e512a3a6': {'model_name': 'HTMLModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_dom_classes': [],
#        '_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'HTMLModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/controls',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'HTMLView',
#        'description': '',
#        'description_allow_html': False,
#        'layout': 'IPY_MODEL_f37535cd1d044451be0e9ed4c46c88d7',
#        'placeholder': '\u200b',
#        'style': 'IPY_MODEL_2f017efd8e4b4642a16263f3c5a773f6',
#        'tabbable': None,
#        'tooltip': None,
#        'value': ' 271/271 [00:00&lt;00:00, 34.1kB/s]'}},
#      '01786572ec55443186535f756e644f2a': {'model_name': 'LayoutModel',
#       'model_module': '@jupyter-widgets/base',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/base',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'LayoutModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'LayoutView',
#        'align_content': None,
#        'align_items': None,
#        'align_self': None,
#        'border_bottom': None,
#        'border_left': None,
#        'border_right': None,
#        'border_top': None,
#        'bottom': None,
#        'display': None,
#        'flex': None,
#        'flex_flow': None,
#        'grid_area': None,
#        'grid_auto_columns': None,
#        'grid_auto_flow': None,
#        'grid_auto_rows': None,
#        'grid_column': None,
#        'grid_gap': None,
#        'grid_row': None,
#        'grid_template_areas': None,
#        'grid_template_columns': None,
#        'grid_template_rows': None,
#        'height': None,
#        'justify_content': None,
#        'justify_items': None,
#        'left': None,
#        'margin': None,
#        'max_height': None,
#        'max_width': None,
#        'min_height': None,
#        'min_width': None,
#        'object_fit': None,
#        'object_position': None,
#        'order': None,
#        'overflow': None,
#        'padding': None,
#        'right': None,
#        'top': None,
#        'visibility': None,
#        'width': None}},
#      'ada9fa4ca2a44e42bae6fcfdfe0c53fe': {'model_name': 'HBoxModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_dom_classes': [],
#        '_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'HBoxModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/controls',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'HBoxView',
#        'box_style': '',
#        'children': ['IPY_MODEL_f13de3fd7c144ecca5047c17f4a90d2d',
#         'IPY_MODEL_352e8bc7415e4d45b1f5dd6e06578221',
#         'IPY_MODEL_943161e1a2054ef39b0c2e51e512a3a6'],
#        'layout': 'IPY_MODEL_01786572ec55443186535f756e644f2a',
#        'tabbable': None,
#        'tooltip': None}},
#      '81028877fae94a1bbffef801332ea759': {'model_name': 'LayoutModel',
#       'model_module': '@jupyter-widgets/base',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/base',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'LayoutModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'LayoutView',
#        'align_content': None,
#        'align_items': None,
#        'align_self': None,
#        'border_bottom': None,
#        'border_left': None,
#        'border_right': None,
#        'border_top': None,
#        'bottom': None,
#        'display': None,
#        'flex': None,
#        'flex_flow': None,
#        'grid_area': None,
#        'grid_auto_columns': None,
#        'grid_auto_flow': None,
#        'grid_auto_rows': None,
#        'grid_column': None,
#        'grid_gap': None,
#        'grid_row': None,
#        'grid_template_areas': None,
#        'grid_template_columns': None,
#        'grid_template_rows': None,
#        'height': None,
#        'justify_content': None,
#        'justify_items': None,
#        'left': None,
#        'margin': None,
#        'max_height': None,
#        'max_width': None,
#        'min_height': None,
#        'min_width': None,
#        'object_fit': None,
#        'object_position': None,
#        'order': None,
#        'overflow': None,
#        'padding': None,
#        'right': None,
#        'top': None,
#        'visibility': None,
#        'width': None}},
#      '4c1407ef3f51432a85109fc82540e5c7': {'model_name': 'ProgressStyleModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'ProgressStyleModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'StyleView',
#        'bar_color': None,
#        'description_width': ''}},
#      '8949e5a6c15e41f59c8038ca6ba36ef6': {'model_name': 'FloatProgressModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_dom_classes': [],
#        '_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'FloatProgressModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/controls',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'ProgressView',
#        'bar_style': 'success',
#        'description': '',
#        'description_allow_html': False,
#        'layout': 'IPY_MODEL_81028877fae94a1bbffef801332ea759',
#        'max': 1.0,
#        'min': 0.0,
#        'orientation': 'horizontal',
#        'style': 'IPY_MODEL_4c1407ef3f51432a85109fc82540e5c7',
#        'tabbable': None,
#        'tooltip': None,
#        'value': 1.0}},
#      '58d325ce53b44d36876142d7fa8ca361': {'model_name': 'LayoutModel',
#       'model_module': '@jupyter-widgets/base',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/base',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'LayoutModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'LayoutView',
#        'align_content': None,
#        'align_items': None,
#        'align_self': None,
#        'border_bottom': None,
#        'border_left': None,
#        'border_right': None,
#        'border_top': None,
#        'bottom': None,
#        'display': None,
#        'flex': None,
#        'flex_flow': None,
#        'grid_area': None,
#        'grid_auto_columns': None,
#        'grid_auto_flow': None,
#        'grid_auto_rows': None,
#        'grid_column': None,
#        'grid_gap': None,
#        'grid_row': None,
#        'grid_template_areas': None,
#        'grid_template_columns': None,
#        'grid_template_rows': None,
#        'height': None,
#        'justify_content': None,
#        'justify_items': None,
#        'left': None,
#        'margin': None,
#        'max_height': None,
#        'max_width': None,
#        'min_height': None,
#        'min_width': None,
#        'object_fit': None,
#        'object_position': None,
#        'order': None,
#        'overflow': None,
#        'padding': None,
#        'right': None,
#        'top': None,
#        'visibility': None,
#        'width': None}},
#      '680b7866954340a9a0d8114898263cdc': {'model_name': 'HTMLStyleModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'HTMLStyleModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'StyleView',
#        'background': None,
#        'description_width': '',
#        'font_size': None,
#        'text_color': None}},
#      '338aa4d9a41a4ae3895cdaaa1c7fd8bb': {'model_name': 'HTMLModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_dom_classes': [],
#        '_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'HTMLModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/controls',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'HTMLView',
#        'description': '',
#        'description_allow_html': False,
#        'layout': 'IPY_MODEL_58d325ce53b44d36876142d7fa8ca361',
#        'placeholder': '\u200b',
#        'style': 'IPY_MODEL_680b7866954340a9a0d8114898263cdc',
#        'tabbable': None,
#        'tooltip': None,
#        'value': '100%'}},
#      '3d1e33b7ad294323b514b197679f3f52': {'model_name': 'LayoutModel',
#       'model_module': '@jupyter-widgets/base',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/base',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'LayoutModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'LayoutView',
#        'align_content': None,
#        'align_items': None,
#        'align_self': None,
#        'border_bottom': None,
#        'border_left': None,
#        'border_right': None,
#        'border_top': None,
#        'bottom': None,
#        'display': None,
#        'flex': None,
#        'flex_flow': None,
#        'grid_area': None,
#        'grid_auto_columns': None,
#        'grid_auto_flow': None,
#        'grid_auto_rows': None,
#        'grid_column': None,
#        'grid_gap': None,
#        'grid_row': None,
#        'grid_template_areas': None,
#        'grid_template_columns': None,
#        'grid_template_rows': None,
#        'height': None,
#        'justify_content': None,
#        'justify_items': None,
#        'left': None,
#        'margin': None,
#        'max_height': None,
#        'max_width': None,
#        'min_height': None,
#        'min_width': None,
#        'object_fit': None,
#        'object_position': None,
#        'order': None,
#        'overflow': None,
#        'padding': None,
#        'right': None,
#        'top': None,
#        'visibility': None,
#        'width': None}},
#      'e8c46c04b3f445d588de9714218a87be': {'model_name': 'HTMLStyleModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'HTMLStyleModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'StyleView',
#        'background': None,
#        'description_width': '',
#        'font_size': None,
#        'text_color': None}},
#      '37ad174724584ca1a914535f90470f77': {'model_name': 'HTMLModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_dom_classes': [],
#        '_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'HTMLModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/controls',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'HTMLView',
#        'description': '',
#        'description_allow_html': False,
#        'layout': 'IPY_MODEL_3d1e33b7ad294323b514b197679f3f52',
#        'placeholder': '\u200b',
#        'style': 'IPY_MODEL_e8c46c04b3f445d588de9714218a87be',
#        'tabbable': None,
#        'tooltip': None,
#        'value': ' 1/1 [00:06&lt;00:00,  6.13s/it]'}},
#      '85c9478528b94eb79ac32ee3026d5efa': {'model_name': 'LayoutModel',
#       'model_module': '@jupyter-widgets/base',
#       'model_module_version': '2.0.0',
#       'state': {'_model_module': '@jupyter-widgets/base',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'LayoutModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/base',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'LayoutView',
#        'align_content': None,
#        'align_items': None,
#        'align_self': None,
#        'border_bottom': None,
#        'border_left': None,
#        'border_right': None,
#        'border_top': None,
#        'bottom': None,
#        'display': None,
#        'flex': None,
#        'flex_flow': None,
#        'grid_area': None,
#        'grid_auto_columns': None,
#        'grid_auto_flow': None,
#        'grid_auto_rows': None,
#        'grid_column': None,
#        'grid_gap': None,
#        'grid_row': None,
#        'grid_template_areas': None,
#        'grid_template_columns': None,
#        'grid_template_rows': None,
#        'height': None,
#        'justify_content': None,
#        'justify_items': None,
#        'left': None,
#        'margin': None,
#        'max_height': None,
#        'max_width': None,
#        'min_height': None,
#        'min_width': None,
#        'object_fit': None,
#        'object_position': None,
#        'order': None,
#        'overflow': None,
#        'padding': None,
#        'right': None,
#        'top': None,
#        'visibility': None,
#        'width': None}},
#      'ee034f4e2f08473c88acae0affcdd524': {'model_name': 'HBoxModel',
#       'model_module': '@jupyter-widgets/controls',
#       'model_module_version': '2.0.0',
#       'state': {'_dom_classes': [],
#        '_model_module': '@jupyter-widgets/controls',
#        '_model_module_version': '2.0.0',
#        '_model_name': 'HBoxModel',
#        '_view_count': None,
#        '_view_module': '@jupyter-widgets/controls',
#        '_view_module_version': '2.0.0',
#        '_view_name': 'HBoxView',
#        'box_style': '',
#        'children': ['IPY_MODEL_338aa4d9a41a4ae3895cdaaa1c7fd8bb',
#         'IPY_MODEL_8949e5a6c15e41f59c8038ca6ba36ef6',
#         'IPY_MODEL_37ad174724584ca1a914535f90470f77'],
#        'layout': 'IPY_MODEL_85c9478528b94eb79ac32ee3026d5efa',
#        'tabbable': None,
#        'tooltip': None}}},
#     'version_major': 2,
#     'version_minor': 0}}},
#  'nbformat': 4,
#  'nbformat_minor': 5}

# %% [markdown]
# # 20240126
# * openai v3 embeddings

# %%
for i, model_id, dimension in [
    (22, "text-embedding-3-small", 1536),
    (23, "text-embedding-3-large", 3072),
    (9, "text-embedding-ada-002", 1536),
    # (24, "text-embedding-3-small", 512),
    # (25, "text-embedding-3-large", 1024),
    # (26, "text-embedding-3-large", 256),
]:
    out_filename = f"{i}_{model_id.replace('/', '_')}_{dimension}.ipynb"
    print(model_id, out_filename)
    pm.execute_notebook(
        "template_openai.ipynb",
        out_filename,
        parameters=dict(model_id=model_id, dimension=dimension),
    )
# Out:
# Black is not installed, parameters wont be formatted
# text-embedding-3-small 22_text-embedding-3-small_1536.ipynb
# Executing:   0%|          | 0/29 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# text-embedding-3-large 23_text-embedding-3-large_3072.ipynb
# Executing:   0%|          | 0/29 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# text-embedding-ada-002 9_text-embedding-ada-002_1536.ipynb
# Executing:   0%|          | 0/29 [00:00<?, ?cell/s]

# %% [markdown]
# # 20231110
# * miraclの評価でassertion errorが出ると報告があったため、templateを修正して再実行
#     * https://github.com/oshizo/JapaneseEmbeddingEval/issues/5
# * 9_text_embedding-ada-002.ipynbはコードのみ修正し再実行はせず

# %%
for i, model_id in [
    (1, "colorfulscoop/sbert-base-ja"),
    (2, "MU-Kindai/SBERT-JSNLI-base"),
    (3, "MU-Kindai/SBERT-JSNLI-large"),
    (5, "oshizo/sbert-jsnli-luke-japanese-base-lite"),
    (6, "pkshatech/simcse-ja-bert-base-clcmlp"),
    (10, "intfloat/multilingual-e5-base"),
    (11, "intfloat/multilingual-e5-large"),
    (12, "pkshatech/GLuCoSE-base-ja"),
    (13, "cl-nagoya/unsup-simcse-ja-base"),
    (14, "cl-nagoya/unsup-simcse-ja-large"),
    (15, "cl-nagoya/sup-simcse-ja-base"),
    (16, "cl-nagoya/sup-simcse-ja-large"),
    (17, "intfloat/multilingual-e5-small"),
    (18, "bclavie/fio-base-japanese-v0.1"),
]:
    # parameters
    query_prefix = "query: " if "multilingual-e5" in model_id else ""
    passage_prefix = "passage: " if "multilingual-e5" in model_id else ""

    out_filename = f"{i}_{model_id.replace('/', '_')}.ipynb"
    print(model_id, out_filename)
    pm.execute_notebook(
        "template_sentence-transformers.ipynb",
        out_filename,
        parameters=dict(
            model_id=model_id, query_prefix=query_prefix, passage_prefix=passage_prefix
        ),
    )
# Out:
# Black is not installed, parameters wont be formatted
# colorfulscoop/sbert-base-ja 1_colorfulscoop_sbert-base-ja.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# MU-Kindai/SBERT-JSNLI-base 2_MU-Kindai_SBERT-JSNLI-base.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# MU-Kindai/SBERT-JSNLI-large 3_MU-Kindai_SBERT-JSNLI-large.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# oshizo/sbert-jsnli-luke-japanese-base-lite 5_oshizo_sbert-jsnli-luke-japanese-base-lite.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# pkshatech/simcse-ja-bert-base-clcmlp 6_pkshatech_simcse-ja-bert-base-clcmlp.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# intfloat/multilingual-e5-base 10_intfloat_multilingual-e5-base.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# intfloat/multilingual-e5-large 11_intfloat_multilingual-e5-large.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# pkshatech/GLuCoSE-base-ja 12_pkshatech_GLuCoSE-base-ja.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# cl-nagoya/unsup-simcse-ja-base 13_cl-nagoya_unsup-simcse-ja-base.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# cl-nagoya/unsup-simcse-ja-large 14_cl-nagoya_unsup-simcse-ja-large.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# cl-nagoya/sup-simcse-ja-base 15_cl-nagoya_sup-simcse-ja-base.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# cl-nagoya/sup-simcse-ja-large 16_cl-nagoya_sup-simcse-ja-large.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# intfloat/multilingual-e5-small 17_intfloat_multilingual-e5-small.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]

# %% [markdown]
# # 20231008

# %%
for i, model_id in [
    (10, "intfloat/multilingual-e5-base"),
    (1, "colorfulscoop/sbert-base-ja"),
    (2, "MU-Kindai/SBERT-JSNLI-base"),
    (3, "MU-Kindai/SBERT-JSNLI-large"),
    (5, "oshizo/sbert-jsnli-luke-japanese-base-lite"),
    (6, "pkshatech/simcse-ja-bert-base-clcmlp"),
    (17, "intfloat/multilingual-e5-small"),
    (11, "intfloat/multilingual-e5-large"),
    (12, "pkshatech/GLuCoSE-base-ja"),
    (13, "cl-nagoya/unsup-simcse-ja-base"),
    (14, "cl-nagoya/unsup-simcse-ja-large"),
    (15, "cl-nagoya/sup-simcse-ja-base"),
    (16, "cl-nagoya/sup-simcse-ja-large"),
]:
    # parameters
    query_prefix = "query: " if "multilingual-e5" in model_id else ""
    passage_prefix = "passage: " if "multilingual-e5" in model_id else ""

    out_filename = f"{i}_{model_id.replace('/', '_')}.ipynb"
    print(model_id, out_filename)
    pm.execute_notebook(
        "template_sentence-transformers.ipynb",
        out_filename,
        parameters=dict(
            model_id=model_id, query_prefix=query_prefix, passage_prefix=passage_prefix
        ),
    )
# Out:
# Black is not installed, parameters wont be formatted
# intfloat/multilingual-e5-base 10_intfloat_multilingual-e5-base.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# colorfulscoop/sbert-base-ja 1_colorfulscoop_sbert-base-ja.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# MU-Kindai/SBERT-JSNLI-base 2_MU-Kindai_SBERT-JSNLI-base.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# MU-Kindai/SBERT-JSNLI-large 3_MU-Kindai_SBERT-JSNLI-large.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# oshizo/sbert-jsnli-luke-japanese-base-lite 5_oshizo_sbert-jsnli-luke-japanese-base-lite.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# pkshatech/simcse-ja-bert-base-clcmlp 6_pkshatech_simcse-ja-bert-base-clcmlp.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# intfloat/multilingual-e5-small 17_intfloat_multilingual-e5-small.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# intfloat/multilingual-e5-large 11_intfloat_multilingual-e5-large.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# pkshatech/GLuCoSE-base-ja 12_pkshatech_GLuCoSE-base-ja.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# cl-nagoya/unsup-simcse-ja-base 13_cl-nagoya_unsup-simcse-ja-base.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# cl-nagoya/unsup-simcse-ja-large 14_cl-nagoya_unsup-simcse-ja-large.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# cl-nagoya/sup-simcse-ja-base 15_cl-nagoya_sup-simcse-ja-base.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
# Black is not installed, parameters wont be formatted
# cl-nagoya/sup-simcse-ja-large 16_cl-nagoya_sup-simcse-ja-large.ipynb
# Executing:   0%|          | 0/28 [00:00<?, ?cell/s]
